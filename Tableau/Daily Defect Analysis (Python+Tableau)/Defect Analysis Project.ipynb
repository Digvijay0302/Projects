# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
## Read excel File.

df=pd.read_excel('/content/drive/MyDrive/Scrap Daily File/20210101 -Defect Repair List.xlsx')
df.shape
# Out:
# (809, 22)

# %%
## os for easy Upload data.
import os

# %%
## Change Path or Directory

cd '/content/drive/MyDrive/Scrap Daily File'
# Out:
# /content/drive/MyDrive/Scrap Daily File

# %%
## Import last 4 Digit Excel File from Drive.

a=[]
for i in os.listdir():
    if i[-4:]=='xlsx':
        a.append(i)

# %%
a
# Out:
# ['20210102 -Defect Repair List.xlsx',
#  '20210116 -Defect Repair List.xlsx',
#  '20210101 -Defect Repair List.xlsx',
#  '20210124 -Defect Repair List.xlsx',
#  '20210103 -Defect Repair List.xlsx',
#  '20210127 -Defect Repair List.xlsx',
#  '20210117 -Defect Repair List.xlsx',
#  '20210113 -Defect Repair List.xlsx',
#  '20210122 -Defect Repair List.xlsx',
#  '20210108 -Defect Repair List.xlsx',
#  '20210112 -Defect Repair List.xlsx',
#  '20210107 -Defect Repair List.xlsx',
#  '20210109 -Defect Repair List.xlsx',
#  '20210129 -Defect Repair List.xlsx',
#  '20210104 -Defect Repair List.xlsx',
#  '20210106 -Defect Repair List.xlsx',
#  '20210120 -Defect Repair List.xlsx',
#  '20210128 -Defect Repair List.xlsx',
#  '20210111 -Defect Repair List.xlsx',
#  '20210121 -Defect Repair List.xlsx',
#  '20210123 -Defect Repair List.xlsx',
#  '20210118 -Defect Repair List.xlsx',
#  '20210105 -Defect Repair List.xlsx',
#  '20210130 -Defect Repair List.xlsx',
#  '20210119 -Defect Repair List.xlsx',
# ...

# %%
df1=pd.DataFrame()

# %%
## Read excel file.
for i in a:
    df2=pd.read_excel('/content/drive/MyDrive/Scrap Daily File/'+i)
    df1=pd.concat([df1,df2])

# %%
df1.shape
# Out:
# (106263, 320)

# %%
## Check maximum Column.

pd.set_option('display.max_columns', None)

# %%
df1.head(2)
# Out:
#   20210102 Before Defect List           Unnamed: 1   Unnamed: 2   Unnamed: 3  \
# 0                       Sr no   Checking Date/Time  Barcode No.  Material ID
# 1                           1  2021-01-03 05:25:00  A1080221764   TM00227200
#
#                                 Unnamed: 4 Unnamed: 5 Unnamed: 6   Unnamed: 7  \
# 0                                     SPEC       Type     Repair  Defect name
# 1  90/90-12 M6000R 54J TL OE #E,ISI MAXXIS          C      Scrap           AC
#
#     Unnamed: 8 Unnamed: 9    Unnamed: 10    Unnamed: 11          Unnamed: 12  \
# 0     Position   Mold No.  Upper / Lower         Degree  Accountibility Unit
# 1  Inner Liner          8           Both  0 full circle               Curing
#
#        Unnamed: 13 Unnamed: 14    Unnamed: 15  Unnamed: 16  \
# 0  Inspection user       Shift  Checking Time  Building OP
# 1           200021          33             26    FT2003070
#
#            Unnamed: 17 Unnamed: 18          Unnamed: 19 Unnamed: 20  \
# ...

# %%
## Checking Column Name.

df1.iloc[0,:]
# Out:
# 20210102 Before Defect List                 Sr no
# Unnamed: 1                     Checking Date/Time
# Unnamed: 2                            Barcode No.
# Unnamed: 3                            Material ID
# Unnamed: 4                                   SPEC
#                                       ...
# 20211201 Before Defect List                   NaN
# 20211227 Before Defect List                   NaN
# 20211217 Before Defect List                   NaN
# 20211204 Before Defect List                   NaN
# 20211220 Before Defect List                   NaN
# Name: 0, Length: 320, dtype: object

# %%
df3=df1.copy()

# %%
## Update Column Name
df1.columns=df1.iloc[0,:].str.lower()

# %%
df1.head(2)
# Out:
# 0  sr no   checking date/time  barcode no.  material id  \
# 0  Sr no   Checking Date/Time  Barcode No.  Material ID
# 1      1  2021-01-03 05:25:00  A1080221764   TM00227200
#
# 0                                     spec  type  repair  defect name  \
# 0                                     SPEC  Type  Repair  Defect name
# 1  90/90-12 M6000R 54J TL OE #E,ISI MAXXIS     C   Scrap           AC
#
# 0     position  mold no.  upper / lower         degree  accountibility unit  \
# 0     Position  Mold No.  Upper / Lower         Degree  Accountibility Unit
# 1  Inner Liner         8           Both  0 full circle               Curing
#
# 0  inspection user  shift  checking time  building op        building time  \
# 0  Inspection user  Shift  Checking Time  Building OP        Building Time
# 1           200021     33             26    FT2003070  2021-01-02 16:43:00
#
# 0  curing op          curing time        ppm   total ppm  NaN  NaN  NaN  NaN  \
# ...

# %%
## Necessary Column Data
jan=df1[['checking date/time','barcode no.','spec','repair','defect name','position','accountibility unit','mold no.','inspection user','shift','building op','curing op']]

# %%
## Reset index 
jan=jan.reset_index(drop=True)

# %%
jan.tail()
# Out:
# 0      checking date/time barcode no. spec repair defect name position  \
# 106258                NaN         NaN  NaN    NaN         NaN      NaN
# 106259                NaN         NaN  NaN    NaN         NaN      NaN
# 106260                NaN         NaN  NaN    NaN         NaN      NaN
# 106261                NaN         NaN  NaN    NaN         NaN      NaN
# 106262                NaN         NaN  NaN    NaN         NaN      NaN
#
# 0      accountibility unit mold no. inspection user shift building op  \
# 106258                 NaN      NaN             NaN   NaN         NaN
# 106259                 NaN      NaN             NaN   NaN         NaN
# 106260                 NaN      NaN             NaN   NaN         NaN
# 106261                 NaN      NaN             NaN   NaN         NaN
# 106262                 NaN      NaN             NaN   NaN         NaN
#
# 0      curing op
# 106258       NaN
# 106259       NaN
# 106260       NaN
# 106261       NaN
# 106262       NaN

# %%
## Checking Index of checking date/time because NAN value.
 
jan[jan['checking date/time']=='Checking Date/Time'].index
# Out:
# Int64Index([     0,    634,   1444,   2253,   2634,   4024,   4494,   5323,
#               6396,   6835,
#             ...
#             103014, 103212, 103518, 103877, 104202, 104436, 104791, 105176,
#             105501, 105876],
#            dtype='int64', length=266)

# %%
## Drop Index.
jan=jan.drop(jan[jan['checking date/time']=='Checking Date/Time'].index)

# %%
jan.shape
# Out:
# (105997, 12)

# %%
## Handel Null Value.

jan.isnull().sum()
# Out:
# 0
# checking date/time      4993
# barcode no.             5044
# spec                    5041
# repair                  5093
# defect name             5094
# position                1209
# accountibility unit    30312
# mold no.               27383
# inspection user         5210
# shift                   5116
# building op             4849
# curing op               9945
# dtype: int64

# %%
jan=jan.drop(['accountibility unit','mold no.'],axis=1)

# %%
jan.dropna(inplace=True)

# %%
jan.isnull().sum()
# Out:
# 0
# checking date/time    0
# barcode no.           0
# spec                  0
# repair                0
# defect name           0
# position              0
# inspection user       0
# shift                 0
# building op           0
# curing op             0
# dtype: int64

# %%
jan.shape
# Out:
# (95669, 10)

# %%
jan.to_csv('2021_New.csv')

# %%
jan.tail()
# Out:
# 0        checking date/time  barcode no.  \
# 106144  2021-12-20 00:00:00  A1070387579
# 106145  2021-12-20 00:00:00  A2050324967
# 106146  2021-12-20 00:00:00  A2020280869
# 106147  2021-12-20 00:00:00  A1050477474
# 106148  2021-12-20 00:00:00  A2050324562
#
# 0                                                 spec repair defect name  \
# 106144         110/90-10 M6310 61J TL RE HCM-36 MAXXIS      P          OT
# 106145  130/70-12 W6170i 62L TL RE HCM-36 Wild Cruiser      P          OT
# 106146         90/90-12 M6000R 54J TL OE #E,ISI MAXXIS      P          OT
# 106147         110/90-10 M6220 61J TL RE HCM-36 MAXXIS      P          PB
# 106148                    90/90-12 M6000 54J TL MAXXIS      P          PB
#
# 0      position inspection user shift building op curing op
# 106144     Bead          200021    32   FT2110147   2106048
# 106145     Bead          200021    32   FT1912111   2103038
# 106146     Bead          190160    31   FT2104060   2010072
# ...
